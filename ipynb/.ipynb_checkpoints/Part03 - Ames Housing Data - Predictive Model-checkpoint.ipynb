# %% [markdown]
# # Regression and Classification with the Ames Housing Data
#
# ---
#
# ## Premise:
# I have just joined a new "full stack" real estate company in Ames, Iowa. The strategy of the firm is two-fold:
# - Own the entire process from the purchase of the land all the way to sale of the house, and anything in between.
# - Use statistical analysis to optimize investment and maximize return.
#
# The company is still small, and though investment is substantial the short-term goals of the company are more oriented towards purchasing existing houses and flipping them as opposed to constructing entirely new houses. That being said, the company has access to a large construction workforce operating at rock-bottom prices.
#
# This project uses the [Ames housing data recently made available on kaggle](https://www.kaggle.com/c/house-prices-advanced-regression-techniques).

# %% [markdown]
# ## Data:
# The full description of the data features can be found in a separate file:
#
#     housing.csv
#     data_description.txt
#
# ## Objective:
# 1. Develop an algorithm to estimate the value of the residential homes based on fixed characteristics (those that are not considered easy to renovate).
# 2. Identify characteristics of homes that the company can cost-effectively change/renovate with their construction team.
# 3. Evaluate the mean dollar value of different renovations.
#
# Use the information to buy homes that are likely to sell for more than the initial purchase.
#
# ## Process:
# 1. Perform any cleaning, feature engineering, and EDA you deem necessary.
# - Be sure to remove any houses that are not residential from the dataset.
# - Identify **fixed** features that can predict price.
# - Train a model on pre-2010 data and evaluate its performance on the 2010 houses.
# - Characterize and evaluate the model. (How does it perform and what are the best estimates of price?)
#
# ## Citations:
# - http://www.remodeling.hw.net/cost-vs-value/2010/west-north-central/des-moines-ia/
# - http://cdnassets.hw.net/b6/3d/047accdd4174a4965051631d7900/cvv-2010-2011-professional-desmoinesia.pdf

# %%
# !pip install display --quiet

# %%
import sys
import numpy as np, pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt, seaborn as sns

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ### Load and Inspect the Data

# %%
from os import chdir

# %%
pwd
# Out:
# '/home/jovyan/DSI/DSI_Plus_1_Curriculum/project-three/project-three/ipynb'

# %%
chdir('../')

# %%
from library import functions as fy

# %%
X_train = pd.read_pickle('./assets/X_train.p')
X_train.shape
# Out:
# (1221, 146)

# %%
X_test = pd.read_pickle('./assets/X_test.p')
X_test.shape
# Out:
# (164, 146)

# %%
import pickle

# %%
y_test = pickle.load(open('./y_test.p', 'rb'))
y_test.shape
# Out:
# (164,)

# %%
y_train = pickle.load(open('./y_train.p', 'rb'))
y_train.shape
# Out:
# (1221,)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1221 entries, 0 to 1459
# Columns: 146 entries, LotFrontage to SaleCondition_Partial
# dtypes: float64(2), int64(18), uint8(126)
# memory usage: 350.6 KB

# %% [markdown]
# With 141 features, run a feature-selection model to determine which features are the best predictors for `SalePrice`.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, ShuffleSplit
from sklearn.feature_selection import SelectKBest, SelectFromModel, f_regression
from sklearn.linear_model import Lasso, ElasticNet, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline

# %%
np.random.seed(42)

# %%
rfr_pipe = Pipeline([
    ('skb', SelectKBest(score_func=f_regression)),
    ('scaler', StandardScaler()),
    ('sfm', SelectFromModel(Lasso())),
    ('rfr', RandomForestRegressor(n_jobs=-1)),
])

# %%
rfr_param = {
    'skb__k' : [75, 60, 50],
    'sfm__estimator' : [Lasso(alpha=a) for a in np.logspace(1,3,6)],
    'rfr__n_estimators' : [25, 35, 50],
    'rfr__max_depth' : [175, 200, 225],
}

# %%
rfr_gs = GridSearchCV(rfr_pipe, param_grid=rfr_param, cv=ShuffleSplit(n_splits=5), n_jobs=-1)

# %%
rfr_gs.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
# ...
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /opt/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# GridSearchCV(cv=ShuffleSplit(n_splits=5, random_state=None, test_size=0.1, train_size=None),
#        error_score='raise',
#        estimator=Pipeline(steps=[('skb', SelectKBest(k=10, score_func=<function f_regression at 0x7f12cfa1d378>)), ('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('sfm', SelectFromModel(estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precom...imators=10, n_jobs=-1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False))]),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'skb__k': [75, 60, 50], 'sfm__estimator': [Lasso(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False), Lasso(alpha=25.118864315095795, copy_X=True, fit_int...ol=0.0001, warm_start=False)], 'rfr__n_estimators': [25, 35, 50], 'rfr__max_depth': [175, 200, 225]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
pd.DataFrame(rfr_gs.cv_results_).sort_values(by='rank_test_score').T
# Out:
#                                                                        37   \
# mean_fit_time                                                     0.579818
# mean_score_time                                                   0.104995
# mean_test_score                                                   0.759393
# mean_train_score                                                  0.976889
# param_rfr__max_depth                                                   175
# param_rfr__n_estimators                                                 50
# param_sfm__estimator     Lasso(alpha=10.0, copy_X=True, fit_intercept=T...
# param_skb__k                                                            60
# params                   {'rfr__max_depth': 175, 'rfr__n_estimators': 5...
# rank_test_score                                                          1
# split0_test_score                                                 0.825004
# split0_train_score                                                0.978076
# split1_test_score                                                 0.899144
# split1_train_score                                                0.975722
# split2_test_score                                                 0.846388
# split2_train_score                                                0.975692
# split3_test_score                                                 0.756497
# split3_train_score                                                0.978026
# split4_test_score                                                  0.46993
# split4_train_score                                                 0.97693
# std_fit_time                                                     0.0555752
# std_score_time                                                  0.00311287
# std_test_score                                                     0.15179
# std_train_score                                                 0.00104858
#
#                                                                        127  \
# mean_fit_time                                                     0.477414
# mean_score_time                                                   0.102293
# mean_test_score                                                   0.756114
# mean_train_score                                                  0.975283
# param_rfr__max_depth                                                   225
# param_rfr__n_estimators                                                 35
# param_sfm__estimator     Lasso(alpha=10.0, copy_X=True, fit_intercept=T...
# param_skb__k                                                            60
# params                   {'rfr__max_depth': 225, 'rfr__n_estimators': 3...
# rank_test_score                                                          2
# split0_test_score                                                 0.784847
# split0_train_score                                                0.976486
# split1_test_score                                                 0.877929
# split1_train_score                                                0.974377
# split2_test_score                                                  0.83979
# split2_train_score                                                 0.97527
# split3_test_score                                                 0.750799
# split3_train_score                                                0.974212
# split4_test_score                                                 0.527204
# split4_train_score                                                0.976072
# std_fit_time                                                     0.0378521
# std_score_time                                                  0.00042411
# std_test_score                                                    0.122551
# std_train_score                                                0.000898781
#
#                                                                        96   \
# mean_fit_time                                                     0.514586
# mean_score_time                                                   0.107712
# mean_test_score                                                     0.7552
# mean_train_score                                                  0.976043
# param_rfr__max_depth                                                   200
# param_rfr__n_estimators                                                 50
# param_sfm__estimator     Lasso(alpha=63.095734448019329, copy_X=True, f...
# param_skb__k                                                            75
# params                   {'rfr__max_depth': 200, 'rfr__n_estimators': 5...
# rank_test_score                                                          3
# split0_test_score                                                 0.786271
# split0_train_score                                                0.972972
# split1_test_score                                                 0.878199
# split1_train_score                                                0.973032
# split2_test_score                                                 0.848678
# split2_train_score                                                0.979327
# split3_test_score                                                 0.731755
# split3_train_score                                                0.977409
# split4_test_score                                                 0.531097
# split4_train_score                                                0.977472
# std_fit_time                                                     0.0587134
# std_score_time                                                  0.00403101
# std_test_score                                                    0.122967
# std_train_score                                                 0.00257658
#
#                                                                        7    \
# mean_fit_time                                                     0.398542
# mean_score_time                                                   0.102049
# mean_test_score                                                   0.754345
# mean_train_score                                                  0.973595
# param_rfr__max_depth                                                   175
# param_rfr__n_estimators                                                 25
# param_sfm__estimator     Lasso(alpha=63.095734448019329, copy_X=True, f...
# param_skb__k                                                            60
# params                   {'rfr__max_depth': 175, 'rfr__n_estimators': 2...
# rank_test_score                                                          4
# split0_test_score                                                 0.786772
# split0_train_score                                                0.970085
# split1_test_score                                                 0.879281
# split1_train_score                                                0.971962
# split2_test_score                                                 0.838285
# split2_train_score                                                0.975272
# split3_test_score                                                  0.71109
# split3_train_score                                                0.972408
# split4_test_score                                                 0.556299
# split4_train_score                                                0.978249
# std_fit_time                                                     0.0475073
# std_score_time                                                 0.000134197
# std_test_score                                                    0.113842
# std_train_score                                                 0.00285917
#
#                                                                        151  \
# mean_fit_time                                                     0.617318
# mean_score_time                                                    0.10322
# mean_test_score                                                   0.752952
# mean_train_score                                                  0.975603
# param_rfr__max_depth                                                   225
# param_rfr__n_estimators                                                 50
# param_sfm__estimator     Lasso(alpha=63.095734448019329, copy_X=True, f...
# param_skb__k                                                            60
# params                   {'rfr__max_depth': 225, 'rfr__n_estimators': 5...
# rank_test_score                                                          5
# split0_test_score                                                 0.809383
# split0_train_score                                                0.970358
# split1_test_score                                                 0.888468
# split1_train_score                                                0.974201
# split2_test_score                                                 0.841504
# split2_train_score                                                0.974552
# split3_test_score                                                 0.705352
# split3_train_score                                                0.978766
# split4_test_score                                                 0.520055
# split4_train_score                                                 0.98014
# std_fit_time                                                     0.0367804
# std_score_time                                                  0.00210656
# std_test_score                                                     0.13107
# std_train_score                                                 0.00349768
#
#                                                                        134  \
# mean_fit_time                                                     0.416486
# mean_score_time                                                    0.10371
# mean_test_score                                                   0.752632
# mean_train_score                                                  0.973627
# param_rfr__max_depth                                                   225
# param_rfr__n_estimators                                                 35
# param_sfm__estimator     Lasso(alpha=63.095734448019329, copy_X=True, f...
# param_skb__k                                                            50
# params                   {'rfr__max_depth': 225, 'rfr__n_estimators': 3...
# rank_test_score                                                          6
# split0_test_score                                                  0.82124
# split0_train_score                                                0.971074
# split1_test_score                                                 0.878471
# split1_train_score                                                0.969969
# split2_test_score                                                 0.823082
# split2_train_score                                                0.977592
# split3_test_score                                                 0.732374
# split3_train_score                                                0.970996
# split4_test_score                                                 0.507993
# split4_train_score                                                0.978505
# std_fit_time                                                     0.0423447
# std_score_time                                                  0.00194321
# std_test_score                                                    0.130969
# std_train_score                                                  0.0036424
#
#                                                                        11   \
# mean_fit_time                                                     0.379289
# mean_score_time                                                   0.101985
# mean_test_score                                                   0.752323
# mean_train_score                                                  0.973741
# param_rfr__max_depth                                                   175
# param_rfr__n_estimators                                                 25
# param_sfm__estimator     Lasso(alpha=158.48931924611142, copy_X=True, f...
# param_skb__k                                                            50
# params                   {'rfr__max_depth': 175, 'rfr__n_estimators': 2...
# rank_test_score                                                          7
# split0_test_score                                                 0.819177
# split0_train_score                                                0.976025
# split1_test_score                                                 0.898781
# split1_train_score                                                0.975013
# split2_test_score                                                 0.838401
# split2_train_score                                                 0.96794
# split3_test_score                                                  0.75847
# split3_train_score                                                0.973132
# split4_test_score                                                 0.446784
# split4_train_score                                                0.976594
# std_fit_time                                                     0.0402619
# std_score_time                                                  9.8336e-05
# std_test_score                                                    0.159198
# std_train_score                                                 0.00313025
#
#                                                                        113  \
# mean_fit_time                                                     0.333551
# mean_score_time                                                   0.102358
# mean_test_score                                                    0.75187
# mean_train_score                                                   0.97557
# param_rfr__max_depth                                                   225
# param_rfr__n_estimators                                                 25
# param_sfm__estimator     Lasso(alpha=25.118864315095795, copy_X=True, f...
# param_skb__k                                                            50
# params                   {'rfr__max_depth': 225, 'rfr__n_estimators': 2...
# rank_test_score                                                          8
# split0_test_score                                                 0.800763
# split0_train_score                                                0.976559
# split1_test_score                                                 0.879581
# split1_train_score                                                0.974858
# split2_test_score                                                 0.846251
# split2_train_score                                                0.974691
# split3_test_score                                                 0.701632
# split3_train_score                                                0.976209
# split4_test_score                                                 0.531123
# split4_train_score                                                0.975535
# std_fit_time                                                     0.0352023
# std_score_time                                                 0.000310752
# std_test_score                                                    0.125588
# std_train_score                                                0.000730244
#
#                                                                        154  \
# mean_fit_time                                                     0.559008
# mean_score_time                                                   0.105411
# mean_test_score                                                   0.751613
# mean_train_score                                                  0.975166
# param_rfr__max_depth                                                   225
# param_rfr__n_estimators                                                 50
# param_sfm__estimator     Lasso(alpha=158.48931924611142, copy_X=True, f...
# param_skb__k                                                            60
# params                   {'rfr__max_depth': 225, 'rfr__n_estimators': 5...
# rank_test_score                                                          9
# split0_test_score                                                 0.799402
# split0_train_score                                                 0.97048
# split1_test_score                                                 0.887901
# split1_train_score                                                0.974228
# split2_test_score                                                 0.855631
# split2_train_score                                                 0.97478
# split3_test_score                                                 0.695682
# split3_train_score                                                0.976969
# split4_test_score                                                 0.519447
# split4_train_score                                                0.979371
# std_fit_time                                                      0.026575
# std_score_time                                                  0.00451427
# std_test_score                                                    0.133197
# std_train_score                                                 0.00296374
#
#                                                                        60   \
# mean_fit_time                                                     0.357381
# mean_score_time                                                   0.105256
# mean_test_score                                                   0.751195
# mean_train_score                                                  0.975015
# param_rfr__max_depth                                                   200
# param_rfr__n_estimators                                                 25
# param_sfm__estimator     Lasso(alpha=63.095734448019329, copy_X=True, f...
# param_skb__k                                                            75
# params                   {'rfr__max_depth': 200, 'rfr__n_estimators': 2...
# rank_test_score                                                         10
# split0_test_score                                                 0.812208
# split0_train_score                                                0.974057
# split1_test_score                                                 0.861489
# split1_train_score                                                0.974201
# split2_test_score                                                 0.850982
# split2_train_score                                                0.977159
# split3_test_score                                                 0.659723
# split3_train_score                                                  0.9746
# split4_test_score                                                 0.571575
# split4_train_score                                                0.975057
# std_fit_time                                                     0.0257677
# std_score_time                                                  0.00354345
# std_test_score                                                    0.115304
# std_train_score                                                 0.00112717
#
#                                                ...                          \
# mean_fit_time                                  ...
# mean_score_time                                ...
# mean_test_score                                ...
# mean_train_score                               ...
# param_rfr__max_depth                           ...
# param_rfr__n_estimators                        ...
# param_sfm__estimator                           ...
# param_skb__k                                   ...
# params                                         ...
# rank_test_score                                ...
# split0_test_score                              ...
# split0_train_score                             ...
# split1_test_score                              ...
# split1_train_score                             ...
# split2_test_score                              ...
# split2_train_score                             ...
# split3_test_score                              ...
# split3_train_score                             ...
# split4_test_score                              ...
# split4_train_score                             ...
# std_fit_time                                   ...
# std_score_time                                 ...
# std_test_score                                 ...
# std_train_score                                ...
#
#                                                                        61   \
# mean_fit_time                                                      0.35829
# mean_score_time                                                   0.102168
# mean_test_score                                                   0.698575
# mean_train_score                                                  0.973966
# param_rfr__max_depth                                                   200
# param_rfr__n_estimators                                                 25
# param_sfm__estimator     Lasso(alpha=63.095734448019329, copy_X=True, f...
# param_skb__k                                                            60
# params                   {'rfr__max_depth': 200, 'rfr__n_estimators': 2...
# rank_test_score                                                        153
# split0_test_score                                                 0.781531
# split0_train_score                                                0.973036
# split1_test_score                                                 0.870622
# split1_train_score                                                0.970065
# split2_test_score                                                 0.837688
# split2_train_score                                                0.975454
# split3_test_score                                                 0.617021
# split3_train_score                                                0.975548
# split4_test_score                                                 0.386013
# split4_train_score                                                 0.97573
# std_fit_time                                                     0.0385006
# std_score_time                                                 6.66332e-05
# std_test_score                                                    0.178986
# std_train_score                                                 0.00218663
#
#                                                                        71   \
# mean_fit_time                                                     0.234969
# mean_score_time                                                   0.104611
# mean_test_score                                                   0.697501
# mean_train_score                                                  0.973473
# param_rfr__max_depth                                                   200
# param_rfr__n_estimators                                                 25
# param_sfm__estimator     Lasso(alpha=1000.0, copy_X=True, fit_intercept...
# param_skb__k                                                            50
# params                   {'rfr__max_depth': 200, 'rfr__n_estimators': 2...
# rank_test_score                                                        154
# split0_test_score                                                 0.843828
# split0_train_score                                                0.975122
# split1_test_score                                                 0.871704
# split1_train_score                                                0.970427
# split2_test_score                                                 0.832998
# split2_train_score                                                0.974125
# split3_test_score                                                 0.605109
# split3_train_score                                                0.972279
# split4_test_score                                                 0.333867
# split4_train_score                                                0.975413
# std_fit_time                                                    0.00454071
# std_score_time                                                  0.00213712
# std_test_score                                                     0.20537
# std_train_score                                                 0.00187686
#
#                                                                        15   \
# mean_fit_time                                                     0.363381
# mean_score_time                                                   0.102294
# mean_test_score                                                   0.696766
# mean_train_score                                                  0.974692
# param_rfr__max_depth                                                   175
# param_rfr__n_estimators                                                 25
# param_sfm__estimator     Lasso(alpha=1000.0, copy_X=True, fit_intercept...
# param_skb__k                                                            75
# params                   {'rfr__max_depth': 175, 'rfr__n_estimators': 2...
# rank_test_score                                                        155
# split0_test_score                                                 0.794141
# split0_train_score                                                0.972996
# split1_test_score                                                 0.820589
# split1_train_score                                                 0.97713
# split2_test_score                                                 0.808231
# split2_train_score                                                0.977208
# split3_test_score                                                 0.651318
# split3_train_score                                                0.970234
# split4_test_score                                                 0.409551
# split4_train_score                                                0.975894
# std_fit_time                                                     0.0336914
# std_score_time                                                 0.000316292
# std_test_score                                                    0.156075
# std_train_score                                                 0.00270073
#
#                                                                        129  \
# mean_fit_time                                                      0.48007
# mean_score_time                                                   0.104055
# mean_test_score                                                   0.695686
# mean_train_score                                                  0.975704
# param_rfr__max_depth                                                   225
# param_rfr__n_estimators                                                 35
# param_sfm__estimator     Lasso(alpha=25.118864315095795, copy_X=True, f...
# param_skb__k                                                            75
# params                   {'rfr__max_depth': 225, 'rfr__n_estimators': 3...
# rank_test_score                                                        156
# split0_test_score                                                 0.746483
# split0_train_score                                                0.972603
# split1_test_score                                                 0.882189
# split1_train_score                                                0.973254
# split2_test_score                                                 0.821525
# split2_train_score                                                0.978571
# split3_test_score                                                 0.645054
# split3_train_score                                                0.975072
# split4_test_score                                                 0.383181
# split4_train_score                                                0.979019
# std_fit_time                                                     0.0381348
# std_score_time                                                  0.00388306
# std_test_score                                                     0.17517
# std_train_score                                                 0.00265403
#
#                                                                        70   \
# mean_fit_time                                                      0.23457
# mean_score_time                                                   0.104891
# mean_test_score                                                   0.692986
# mean_train_score                                                  0.972734
# param_rfr__max_depth                                                   200
# param_rfr__n_estimators                                                 25
# param_sfm__estimator     Lasso(alpha=1000.0, copy_X=True, fit_intercept...
# param_skb__k                                                            60
# params                   {'rfr__max_depth': 200, 'rfr__n_estimators': 2...
# rank_test_score                                                        157
# split0_test_score                                                 0.779543
# split0_train_score                                                0.970461
# split1_test_score                                                 0.875016
# split1_train_score                                                0.973052
# split2_test_score                                                 0.806892
# split2_train_score                                                0.973717
# split3_test_score                                                  0.53519
# split3_train_score                                                0.971998
# split4_test_score                                                  0.46829
# split4_train_score                                                 0.97444
# std_fit_time                                                    0.00423992
# std_score_time                                                  0.00387924
# std_test_score                                                    0.160617
# std_train_score                                                 0.00139164
#
#                                                                        86   \
# mean_fit_time                                                     0.380429
# mean_score_time                                                    0.10315
# mean_test_score                                                   0.691731
# mean_train_score                                                  0.974366
# param_rfr__max_depth                                                   200
# param_rfr__n_estimators                                                 35
# param_sfm__estimator     Lasso(alpha=398.10717055349733, copy_X=True, f...
# param_skb__k                                                            50
# params                   {'rfr__max_depth': 200, 'rfr__n_estimators': 3...
# rank_test_score                                                        158
# split0_test_score                                                  0.77881
# split0_train_score                                                0.971878
# split1_test_score                                                 0.885585
# split1_train_score                                                0.971679
# split2_test_score                                                 0.773435
# split2_train_score                                                0.975255
# split3_test_score                                                 0.547778
# split3_train_score                                                0.974438
# split4_test_score                                                 0.473048
# split4_train_score                                                 0.97858
# std_fit_time                                                     0.0467417
# std_score_time                                                   0.0020521
# std_test_score                                                    0.155166
# std_train_score                                                 0.00252826
#
#                                                                        16   \
# mean_fit_time                                                     0.286503
# mean_score_time                                                   0.103061
# mean_test_score                                                    0.69124
# mean_train_score                                                  0.972378
# param_rfr__max_depth                                                   175
# param_rfr__n_estimators                                                 25
# param_sfm__estimator     Lasso(alpha=1000.0, copy_X=True, fit_intercept...
# param_skb__k                                                            60
# params                   {'rfr__max_depth': 175, 'rfr__n_estimators': 2...
# rank_test_score                                                        159
# split0_test_score                                                  0.82847
# split0_train_score                                                0.974617
# split1_test_score                                                 0.892782
# split1_train_score                                                0.969952
# split2_test_score                                                 0.793923
# split2_train_score                                                0.973813
# split3_test_score                                                  0.51837
# split3_train_score                                                0.968494
# split4_test_score                                                 0.422652
# split4_train_score                                                0.975012
# std_fit_time                                                     0.0314412
# std_score_time                                                  0.00139772
# std_test_score                                                    0.185482
# std_train_score                                                  0.0026453
#
#                                                                        12   \
# mean_fit_time                                                     0.397633
# mean_score_time                                                   0.102151
# mean_test_score                                                   0.690194
# mean_train_score                                                  0.972198
# param_rfr__max_depth                                                   175
# param_rfr__n_estimators                                                 25
# param_sfm__estimator     Lasso(alpha=398.10717055349733, copy_X=True, f...
# param_skb__k                                                            75
# params                   {'rfr__max_depth': 175, 'rfr__n_estimators': 2...
# rank_test_score                                                        160
# split0_test_score                                                  0.80632
# split0_train_score                                                0.973349
# split1_test_score                                                 0.872503
# split1_train_score                                                0.970186
# split2_test_score                                                 0.814131
# split2_train_score                                                0.972137
# split3_test_score                                                 0.578566
# split3_train_score                                                0.967556
# split4_test_score                                                 0.379451
# split4_train_score                                                0.977763
# std_fit_time                                                     0.0124394
# std_score_time                                                 7.54891e-05
# std_test_score                                                    0.184989
# std_train_score                                                 0.00340275
#
#                                                                        23   \
# mean_fit_time                                                     0.447584
# mean_score_time                                                   0.102103
# mean_test_score                                                    0.68816
# mean_train_score                                                  0.976435
# param_rfr__max_depth                                                   175
# param_rfr__n_estimators                                                 35
# param_sfm__estimator     Lasso(alpha=25.118864315095795, copy_X=True, f...
# param_skb__k                                                            50
# params                   {'rfr__max_depth': 175, 'rfr__n_estimators': 3...
# rank_test_score                                                        161
# split0_test_score                                                 0.745293
# split0_train_score                                                0.972663
# split1_test_score                                                 0.891514
# split1_train_score                                                0.978267
# split2_test_score                                                 0.824549
# split2_train_score                                                0.975795
# split3_test_score                                                 0.642222
# split3_train_score                                                0.975225
# split4_test_score                                                 0.337224
# split4_train_score                                                0.980226
# std_fit_time                                                     0.0216128
# std_score_time                                                   6.549e-05
# std_test_score                                                    0.194157
# std_train_score                                                 0.00260141
#
#                                                                        123
# mean_fit_time                                                      0.26834
# mean_score_time                                                   0.105008
# mean_test_score                                                   0.687458
# mean_train_score                                                  0.972529
# param_rfr__max_depth                                                   225
# param_rfr__n_estimators                                                 25
# param_sfm__estimator     Lasso(alpha=1000.0, copy_X=True, fit_intercept...
# param_skb__k                                                            75
# params                   {'rfr__max_depth': 225, 'rfr__n_estimators': 2...
# rank_test_score                                                        162
# split0_test_score                                                 0.800415
# split0_train_score                                                0.970055
# split1_test_score                                                 0.887722
# split1_train_score                                                0.972784
# split2_test_score                                                 0.805817
# split2_train_score                                                 0.97303
# split3_test_score                                                 0.580515
# split3_train_score                                                0.970084
# split4_test_score                                                  0.36282
# split4_train_score                                                0.976693
# std_fit_time                                                     0.0256947
# std_score_time                                                  0.00350532
# std_test_score                                                    0.191677
# std_train_score                                                 0.00243956
#
# [24 rows x 162 columns]

# %%
rfr_gs.best_params_
# Out:
# {'rfr__max_depth': 175,
#  'rfr__n_estimators': 50,
#  'sfm__estimator': Lasso(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=1000,
#     normalize=False, positive=False, precompute=False, random_state=None,
#     selection='cyclic', tol=0.0001, warm_start=False),
#  'skb__k': 60}

# %%
rfr_gs.score(X_train, y_train)
# Out:
# 0.97938000607759723

# %%
rfr_gs.score(X_test, y_test)
# Out:
# 0.8619693642784938

# %%
rfr_gs.best_estimator_.named_steps
# Out:
# {'rfr': RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=175,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=-1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  'scaler': StandardScaler(copy=True, with_mean=True, with_std=True),
#  'sfm': SelectFromModel(estimator=Lasso(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=1000,
#     normalize=False, positive=False, precompute=False, random_state=None,
#     selection='cyclic', tol=0.0001, warm_start=False),
#          prefit=False, threshold=None),
#  'skb': SelectKBest(k=60, score_func=<function f_regression at 0x7f12cfa1d378>)}

# %%
rfr_gs.best_estimator_.named_steps['skb'].get_support().sum()
# Out:
# 60

# %%
rfr_gs.best_estimator_.named_steps['sfm'].get_support().sum()
# Out:
# 57

# %%
clean_house_df = pd.read_pickle('./assets/clean_house_df.p')

# %%
clean_house_df.sample(5)

# %% [markdown]
# **The size of my dataset is 3.2 MB as shown below:**

# %%
sys.getsizeof(clean_house_df)/1000000

# %% [markdown]
# ### Understanding the Objective

# %% [markdown]
# In order to meet the 1st objective (which is to build a model using the fixed (not easily renovatable) features to predict the value of a residential home (`SalePrice`), I did some research online to help me roughly determine what features are considered difficult to renovate. My research led me to the following website and pdf:
#     - http://www.remodeling.hw.net/cost-vs-value/2010/west-north-central/des-moines-ia/
#     - http://cdnassets.hw.net/b6/3d/047accdd4174a4965051631d7900/cvv-2010-2011-professional-desmoinesia.pdf
# Together with the data dictionary, the following features were categorized into the following 3 categories:
# - features that cannot be changed
# - features that are difficult to fix
# - features that are less difficult to fix

# %%
clean_house_df.columns

# %%
clean_house_df.drop('MiscVal', axis=1, inplace=True)

# %%
len(clean_house_df.columns)

# %%
cannot_change = ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'LotShape', 'LandContour',\
                 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', \
                 'HouseStyle','YearBuilt', 'YearRemodAdd', 'Foundation', 'BsmtQual', 'BsmtFinSF1', 'BsmtFinSF2', \
                 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'GarageType', 'GarageYrBlt',\
                 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',\
                 'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice']

# %%
lesshardtofix = ['BsmtFinSF1', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'LowQualFinSF',  'KitchenQual',\
                'TotRmsAbvGrd', 'GarageFinish', 'GarageQual', 'PavedDrive',]

# %%
import pickle

# %%
pickle.dump(lesshardtofix, open('lesshardtofix.p', 'wb'))

# %%
hardtofix = ['OverallQual', 'OverallCond', 'RoofStyle', 'RoofMatl','Exterior1st', 'ExterQual','ExterCond',\
             'MasVnrType', 'MasVnrArea', 'BsmtExposure', 'BsmtFullBath', 'BsmtHalfBath', \
             'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'Functional', 'Fireplaces', 'GarageArea',]

# %%
pickle.dump(hardtofix, open('hardtofix.p', 'wb'))

# %%
display(len(cannot_change))
display(len(lesshardtofix))
display(len(hardtofix))

# %% [markdown]
# ### Examine the non-renovatable features of a home to estimate home value

# %%
cannot_change_df = clean_house_df[cannot_change] 
cannot_change_df.shape

# %%
cannot_change_df.columns

# %% [markdown]
# #### Define the target `SalePrice` and the predictive features

# %%
y = cannot_change_df['SalePrice']

# %%
X = clean_house_df[cannot_change].drop(['SalePrice', 'Id'], axis=1)

# %%
display(X.shape)
display(y.shape)

# %%
X['YrSold'].value_counts()

# %% [markdown]
# #### Do a manual train/test/split where if the Yr Sold is 2010, then it is the train set, otherwise if the year sold is 2006-2009, then it is in the train set.

# %%
X_test = X[X['YrSold'] == 2010]
X_train = X[X['YrSold'] != 2010]

# %%
display(X_test.shape)
display(X_train.shape)

# %%
y_test = cannot_change_df[cannot_change_df['YrSold'] == 2010]['SalePrice']
y_test.shape

# %%
y_train = cannot_change_df[cannot_change_df['YrSold'] != 2010]['SalePrice']
y_train.shape

# %%
pickle.dump(y_test, open('y_test.p', 'wb'))
pickle.dump(y_train, open('y_train.p', 'wb'))

# %% [markdown]
# There are some features that are categorial, while there are others that are numeric. In order to enhance the performance of a regression model, I will convert the categorial fetaures to numeric by using pandas `get_dummies`. Below, I separate out the cateogiral from the numeric feature based on the data dictionary.

# %%
display(X.columns)
display(len(X.columns))

# %%
fixed_categorical = ['MSSubClass', 'MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', \
                 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2','BldgType', 'HouseStyle', 'Foundation',\
                'BsmtQual', 'GarageType', 'SaleType']
display(len(fixed_categorical))

# %%
fixed_numeric = [column for column in X.columns if column not in fixed_categorical]
display(len(fixed_numeric))

# %%
X_dummies_df = pd.get_dummies(data = X, columns = fixed_categorical)

# %%
display(X_dummies_df.shape)
display(X_dummies_df.head())

# %%
X_test = X_dummies_df[X_dummies_df['YrSold'] == 2010]
display(X_test.shape)
X_train = X_dummies_df[X_dummies_df['YrSold'] != 2010]
display(X_train.shape)

# %%
X_test.to_pickle('./assets/X_test.p')

# %%
X_train.to_pickle('./assets/X_train.p')
